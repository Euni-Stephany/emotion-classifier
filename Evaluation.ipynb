# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
BASE_DIR = "/content/drive/MyDrive/SKRIPSI"
OUT_DIR  = f"{BASE_DIR}/models"

# %% [markdown]
# # Eval

# %%
import os
import json
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from matplotlib.colors import LinearSegmentedColormap


pink_cmap = LinearSegmentedColormap.from_list(
    "soft_pink_dark",
    ["#FCE4EC", "#F8BBD0", "#EC407A"]
)

BASE_MODELS_DIR = "/content/drive/MyDrive/SKRIPSI/models"

# 🌸 pink gradient
pink_cmap = LinearSegmentedColormap.from_list(
    "soft_pink_dark",
    ["#FCE4EC", "#F8BBD0", "#EC407A"]
)

def safe_get(d, keys, default=None):
    cur = d
    for k in keys:
        if not isinstance(cur, dict) or k not in cur:
            return default
        cur = cur[k]
    return cur

rows = []

# struktur baru:
# models/<ModelTag>/(holdout/<HO_xxx>/summary.json) atau (kfold/k<k>/fold<fold>/summary.json)
for model_name in os.listdir(BASE_MODELS_DIR):
    model_dir = os.path.join(BASE_MODELS_DIR, model_name)
    if not os.path.isdir(model_dir) or model_name.startswith("_"):
        continue

    # split_type: holdout / kfold
    for split_type in ["holdout", "kfold"]:
        split_dir = os.path.join(model_dir, split_type)
        if not os.path.isdir(split_dir):
            continue

        if split_type == "holdout":
            # holdout/<HO_xxx>/
            for scheme_name in sorted(os.listdir(split_dir)):
                run_dir = os.path.join(split_dir, scheme_name)
                if not os.path.isdir(run_dir):
                    continue

                summary_path = os.path.join(run_dir, "summary.json")
                if not os.path.exists(summary_path):
                    continue

                with open(summary_path, "r", encoding="utf-8") as f:
                    s = json.load(f)

                train_time_sec = safe_get(s, ["train_time_sec"], None)
                best_f1 = safe_get(s, ["eval_metrics", "eval_f1_macro"], None)

                # epoch terakhir (kadang ada di train_metrics)
                final_epoch = safe_get(s, ["train_metrics", "epoch"], None)
                if final_epoch is None:
                    final_epoch = safe_get(s, ["eval_metrics", "epoch"], None)

                rows.append({
                    "Model": model_name,
                    "Split": "holdout",
                    "Scheme": scheme_name,            # contoh: HO_80_10_10
                    "Fold": None,
                    "Training Time (Minutes)": (train_time_sec / 60.0) if train_time_sec is not None else None,
                    "Final Epoch": final_epoch,
                    "Best F1-Macro": best_f1,
                    "Run Path": run_dir
                })

        else:
            # kfold/k2/fold1/...
            for k_name in sorted(os.listdir(split_dir)):  # contoh: k2, k3, k5
                k_dir = os.path.join(split_dir, k_name)
                if not os.path.isdir(k_dir):
                    continue

                for fold_name in sorted(os.listdir(k_dir)):  # contoh: fold1
                    run_dir = os.path.join(k_dir, fold_name)
                    if not os.path.isdir(run_dir):
                        continue

                    summary_path = os.path.join(run_dir, "summary.json")
                    if not os.path.exists(summary_path):
                        continue

                    with open(summary_path, "r", encoding="utf-8") as f:
                        s = json.load(f)

                    train_time_sec = safe_get(s, ["train_time_sec"], None)
                    best_f1 = safe_get(s, ["eval_metrics", "eval_f1_macro"], None)

                    final_epoch = safe_get(s, ["train_metrics", "epoch"], None)
                    if final_epoch is None:
                        final_epoch = safe_get(s, ["eval_metrics", "epoch"], None)

                    rows.append({
                        "Model": model_name,
                        "Split": "kfold",
                        "Scheme": k_name,               # contoh: k2
                        "Fold": fold_name,              # contoh: fold1
                        "Training Time (Minutes)": (train_time_sec / 60.0) if train_time_sec is not None else None,
                        "Final Epoch": final_epoch,
                        "Best F1-Macro": best_f1,
                        "Run Path": run_dir
                    })

df_time = pd.DataFrame(rows)

if df_time.empty:
    print("Tidak ada summary.json yang ditemukan. Pastikan training sudah menyimpan summary.json di tiap run folder.")
else:
    df_time = df_time.sort_values(["Model", "Split", "Scheme", "Fold"], na_position="last").reset_index(drop=True)

    # tampilkan per model
    for model in df_time["Model"].unique():
        print(f"\n===== TRAINING TIME TABLE | {model} =====")
        view = df_time[df_time["Model"] == model][
            ["Split", "Scheme", "Fold", "Training Time (Minutes)", "Final Epoch", "Best F1-Macro"]
        ]

        display(
            view.style
            .background_gradient(cmap=pink_cmap)
            .format({
                "Training Time (Minutes)": lambda x: "-" if pd.isna(x) else f"{x:.2f}",
                "Best F1-Macro": lambda x: "-" if pd.isna(x) else f"{x:.4f}",
            })
        )

    # simpan CSV
    csv_path = os.path.join(BASE_MODELS_DIR, "summary_training_time_per_model.csv")
    df_time.to_csv(csv_path, index=False)
    print("\nSaved:", csv_path)
# Out:
# ===== TRAINING TIME TABLE | IndoBERT =====
# <style type="text/css">
# #T_c8c5f_row0_col3 {
#   background-color: #ec417b;
#   color: #f1f1f1;
# }
# #T_c8c5f_row0_col4, #T_c8c5f_row2_col3, #T_c8c5f_row2_col4, #T_c8c5f_row2_col5 {
#   background-color: #ec407a;
#   color: #f1f1f1;
# }
# #T_c8c5f_row0_col5 {
#   background-color: #ec437c;
#   color: #f1f1f1;
# }
# #T_c8c5f_row1_col3 {
#   background-color: #f48fb1;
#   color: #000000;
# }
# #T_c8c5f_row1_col4, #T_c8c5f_row6_col4, #T_c8c5f_row7_col4, #T_c8c5f_row13_col4, #T_c8c5f_row14_col4, #T_c8c5f_row15_col4, #T_c8c5f_row20_col4 {
#   background-color: #f6a2bf;
#   color: #000000;
# }
# #T_c8c5f_row1_col5 {
#   background-color: #f27ba3;
#   color: #f1f1f1;
# }
# #T_c8c5f_row3_col3 {
#   background-color: #fad0de;
#   color: #000000;
# }
# #T_c8c5f_row3_col4, #T_c8c5f_row10_col4, #T_c8c5f_row12_col4, #T_c8c5f_row16_col4, #T_c8c5f_row19_col4, #T_c8c5f_row22_col4 {
#   background-color: #f9c3d6;
#   color: #000000;
# }
# #T_c8c5f_row3_col5 {
#   background-color: #fad5e1;
#   color: #000000;
# }
# #T_c8c5f_row4_col3 {
#   background-color: #fbdee8;
#   color: #000000;
# }
# #T_c8c5f_row4_col4, #T_c8c5f_row5_col4, #T_c8c5f_row8_col4, #T_c8c5f_row17_col4, #T_c8c5f_row18_col4 {
#   background-color: #fad4e1;
#   color: #000000;
# }
# #T_c8c5f_row4_col5, #T_c8c5f_row9_col3, #T_c8c5f_row9_col4, #T_c8c5f_row11_col3, #T_c8c5f_row11_col4, #T_c8c5f_row21_col4 {
#   background-color: #fce4ec;
#   color: #000000;
# }
# #T_c8c5f_row5_col3 {
#   background-color: #fbd6e2;
#   color: #000000;
# }
# #T_c8c5f_row5_col5, #T_c8c5f_row16_col3 {
#   background-color: #f8bbd0;
#   color: #000000;
# }
# #T_c8c5f_row6_col3 {
#   background-color: #f6a4c0;
#   color: #000000;
# }
# #T_c8c5f_row6_col5 {
#   background-color: #f9c0d4;
#   color: #000000;
# }
# #T_c8c5f_row7_col3 {
#   background-color: #f6a3bf;
#   color: #000000;
# }
# #T_c8c5f_row7_col5, #T_c8c5f_row12_col5 {
#   background-color: #f9c7d8;
#   color: #000000;
# }
# #T_c8c5f_row8_col3 {
#   background-color: #fad1df;
#   color: #000000;
# }
# #T_c8c5f_row8_col5 {
#   background-color: #f9cada;
#   color: #000000;
# }
# #T_c8c5f_row9_col5 {
#   background-color: #f9c2d5;
#   color: #000000;
# }
# #T_c8c5f_row10_col3 {
#   background-color: #f8bed2;
#   color: #000000;
# }
# #T_c8c5f_row10_col5 {
#   background-color: #f38aae;
#   color: #f1f1f1;
# }
# #T_c8c5f_row11_col5, #T_c8c5f_row19_col5 {
#   background-color: #fad2e0;
#   color: #000000;
# }
# #T_c8c5f_row12_col3 {
#   background-color: #f8b9ce;
#   color: #000000;
# }
# #T_c8c5f_row13_col3, #T_c8c5f_row15_col5 {
#   background-color: #f282a8;
#   color: #f1f1f1;
# }
# #T_c8c5f_row13_col5 {
#   background-color: #f16f9b;
#   color: #f1f1f1;
# }
# #T_c8c5f_row14_col3 {
#   background-color: #f281a7;
#   color: #f1f1f1;
# }
# #T_c8c5f_row14_col5 {
#   background-color: #f8bacf;
#   color: #000000;
# }
# #T_c8c5f_row15_col3 {
#   background-color: #f283a9;
#   color: #f1f1f1;
# }
# #T_c8c5f_row16_col5 {
#   background-color: #fbd5e2;
#   color: #000000;
# }
# #T_c8c5f_row17_col3, #T_c8c5f_row18_col3 {
#   background-color: #facddc;
#   color: #000000;
# }
# #T_c8c5f_row17_col5, #T_c8c5f_row22_col5 {
#   background-color: #f9c8d9;
#   color: #000000;
# }
# #T_c8c5f_row18_col5 {
#   background-color: #f177a0;
#   color: #f1f1f1;
# }
# #T_c8c5f_row19_col3 {
#   background-color: #f7b5cc;
#   color: #000000;
# }
# #T_c8c5f_row20_col3 {
#   background-color: #f178a1;
#   color: #f1f1f1;
# }
# #T_c8c5f_row20_col5 {
#   background-color: #ef5d8e;
#   color: #f1f1f1;
# }
# #T_c8c5f_row21_col3 {
#   background-color: #fce1ea;
#   color: #000000;
# }
# #T_c8c5f_row21_col5 {
#   background-color: #f9c4d6;
#   color: #000000;
# }
# #T_c8c5f_row22_col3 {
#   background-color: #f7b4cb;
#   color: #000000;
# }
# </style>
# <table id="T_c8c5f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c8c5f_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_c8c5f_level0_col1" class="col_heading level0 col1" >Scheme</th>
#       <th id="T_c8c5f_level0_col2" class="col_heading level0 col2" >Fold</th>
#       <th id="T_c8c5f_level0_col3" class="col_heading level0 col3" >Training Time (Minutes)</th>
#       <th id="T_c8c5f_level0_col4" class="col_heading level0 col4" >Final Epoch</th>
#       <th id="T_c8c5f_level0_col5" class="col_heading level0 col5" >Best F1-Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8c5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8c5f_row0_col0" class="data row0 col0" >holdout</td>
#       <td id="T_c8c5f_row0_col1" class="data row0 col1" >HO_70_15_15</td>
#       <td id="T_c8c5f_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_c8c5f_row0_col3" class="data row0 col3" >4.06</td>
#       <td id="T_c8c5f_row0_col4" class="data row0 col4" >8.000000</td>
#       <td id="T_c8c5f_row0_col5" class="data row0 col5" >0.7929</td>
#     </tr>
#     <tr>
#       <th id="T_c8c5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8c5f_row1_col0" class="data row1 col0" >holdout</td>
#       <td id="T_c8c5f_row1_col1" class="data row1 col1" >HO_80_10_10</td>
#       <td id="T_c8c5f_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_c8c5f_row1_col3" class="data row1 col3" >3.29</td>
#       <td id="T_c8c5f_row1_col4" class="data row1 col4" >6.000000</td>
#       <td id="T_c8c5f_row1_col5" class="data row1 col5" >0.7815</td>
#     </tr>
#     <tr>
#       <th id="T_c8c5f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8c5f_row2_col0" class="data row2 col0" >holdout</td>
#       <td id="T_c8c5f_row2_col1" class="data row2 col1" >HO_90_05_05</td>
#       <td id="T_c8c5f_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_c8c5f_row2_col3" class="data row2 col3" >4.07</td>
#       <td id="T_c8c5f_row2_col4" class="data row2 col4" >8.000000</td>
#       <td id="T_c8c5f_row2_col5" class="data row2 col5" >0.7937</td>
#     </tr>
#     <tr>
#       <th id="T_c8c5f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8c5f_row3_col0" class="data row3 col0" >kfold</td>
#       <td id="T_c8c5f_row3_col1" class="data row3 col1" >k2</td>
#       <td id="T_c8c5f_row3_col2" class="data row3 col2" >fold1</td>
#       <td id="T_c8c5f_row3_col3" class="data row3 col3" >2.25</td>
#       <td id="T_c8c5f_row3_col4" class="data row3 col4" >5.000000</td>
#       <td id="T_c8c5f_row3_col5" class="data row3 col5" >0.7529</td>
#     </tr>
#     <tr>
#       <th id="T_c8c5f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8c5f_row4_col0" class="data row4 col0" >kfold</td>
#       <td id="T_c8c5f_row4_col1" class="data row4 col1" >k2</td>
#       <td id="T_c8c5f_row4_col2" class="data row4 col2" >fold2</td>
#       <td id="T_c8c5f_row4_col3" class="data row4 col3" >1.83</td>
#       <td id="T_c8c5f_row4_col4" class="data row4 col4" >4.000000</td>
#       <td id="T_c8c5f_row4_col5" class="data row4 col5" >0.7434</td>
#     </tr>
#     <tr>
#       <th id="T_c8c5f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c8c5f_row5_col0" class="data row5 col0" >kfold</td>
#       <td id="T_c8c5f_row5_col1" class="data row5 col1" >k3</td>
#       <td id="T_c8c5f_row5_col2" class="data row5 col2" >fold1</td>
#       <td id="T_c8c5f_row5_col3" class="data row5 col3" >2.08</td>
#       <td id="T_c8c5f_row5_col4" class="data row5 col4" >4.000000</td>
#       <td id="T_c8c5f_row5_col5" class="data row5 col5" >0.7687</td>
#     </tr>
#     <tr>
#       <th id="T_c8c5f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c8c5f_row6_col0" class="data row6 col0" >kfold</td>
#       <td id="T_c8c5f_row6_col1" class="data row6 col1" >k3</td>
#       <td id="T_c8c5f_row6_col2" class="data row6 col2" >fold2</td>
#       <td id="T_c8c5f_row6_col3" class="data row6 col3" >3.09</td>
#       <td id="T_c8c5f_row6_col4" class="data row6 col4" >6.000000</td>
#       <td id="T_c8c5f_row6_col5" class="data row6 col5" >0.7653</td>
#     </tr>
#     <tr>
#       <th id="T_c8c5f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c8c5f_row7_col0" class="data row7 col0" >kfold</td>
#       <td id="T_c8c5f_row7_col1" class="data row7 col1" >k3</td>
#       <td id="T_c8c5f_row7_col2" class="data row7 col2" >fold3</td>
#       <td id="T_c8c5f_row7_col3" class="data row7 col3" >3.10</td>
#       <td id=
# ===== TRAINING TIME TABLE | IndoBERTweet =====
# <style type="text/css">
# #T_3303c_row0_col3, #T_3303c_row2_col3 {
#   background-color: #fbdde7;
#   color: #000000;
# }
# #T_3303c_row0_col4, #T_3303c_row2_col4, #T_3303c_row3_col4, #T_3303c_row4_col4, #T_3303c_row7_col4, #T_3303c_row8_col4, #T_3303c_row15_col4, #T_3303c_row18_col4, #T_3303c_row20_col4 {
#   background-color: #fbdbe6;
#   color: #000000;
# }
# #T_3303c_row0_col5, #T_3303c_row2_col5 {
#   background-color: #f9c1d4;
#   color: #000000;
# }
# #T_3303c_row1_col3 {
#   background-color: #fad0de;
#   color: #000000;
# }
# #T_3303c_row1_col4, #T_3303c_row5_col4, #T_3303c_row7_col5, #T_3303c_row14_col4, #T_3303c_row19_col4 {
#   background-color: #fad2e0;
#   color: #000000;
# }
# #T_3303c_row1_col5 {
#   background-color: #f7b6cc;
#   color: #000000;
# }
# #T_3303c_row3_col3, #T_3303c_row4_col3 {
#   background-color: #fce2eb;
#   color: #000000;
# }
# #T_3303c_row3_col5 {
#   background-color: #facedd;
#   color: #000000;
# }
# #T_3303c_row4_col5, #T_3303c_row15_col3 {
#   background-color: #fbd7e3;
#   color: #000000;
# }
# #T_3303c_row5_col3 {
#   background-color: #fad5e1;
#   color: #000000;
# }
# #T_3303c_row5_col5 {
#   background-color: #f6a3bf;
#   color: #000000;
# }
# #T_3303c_row6_col3, #T_3303c_row6_col4, #T_3303c_row11_col4, #T_3303c_row12_col4, #T_3303c_row21_col4, #T_3303c_row22_col4, #T_3303c_row22_col5 {
#   background-color: #fce4ec;
#   color: #000000;
# }
# #T_3303c_row6_col5 {
#   background-color: #faccdc;
#   color: #000000;
# }
# #T_3303c_row7_col3 {
#   background-color: #fbdce7;
#   color: #000000;
# }
# #T_3303c_row8_col3 {
#   background-color: #fbd9e4;
#   color: #000000;
# }
# #T_3303c_row8_col5 {
#   background-color: #f6abc5;
#   color: #000000;
# }
# #T_3303c_row9_col3 {
#   background-color: #f599b8;
#   color: #000000;
# }
# #T_3303c_row9_col4 {
#   background-color: #f492b3;
#   color: #000000;
# }
# #T_3303c_row9_col5 {
#   background-color: #f491b3;
#   color: #000000;
# }
# #T_3303c_row10_col3, #T_3303c_row10_col4 {
#   background-color: #f8c0d3;
#   color: #000000;
# }
# #T_3303c_row10_col5 {
#   background-color: #f385ab;
#   color: #f1f1f1;
# }
# #T_3303c_row11_col3 {
#   background-color: #fce1ea;
#   color: #000000;
# }
# #T_3303c_row11_col5 {
#   background-color: #fad4e1;
#   color: #000000;
# }
# #T_3303c_row12_col3 {
#   background-color: #fcdfe9;
#   color: #000000;
# }
# #T_3303c_row12_col5 {
#   background-color: #f9c6d8;
#   color: #000000;
# }
# #T_3303c_row13_col3, #T_3303c_row13_col4, #T_3303c_row13_col5 {
#   background-color: #ec407a;
#   color: #f1f1f1;
# }
# #T_3303c_row14_col3 {
#   background-color: #facfde;
#   color: #000000;
# }
# #T_3303c_row14_col5, #T_3303c_row17_col3, #T_3303c_row19_col5 {
#   background-color: #f9c4d6;
#   color: #000000;
# }
# #T_3303c_row15_col5 {
#   background-color: #f495b5;
#   color: #000000;
# }
# #T_3303c_row16_col3 {
#   background-color: #ee598c;
#   color: #f1f1f1;
# }
# #T_3303c_row16_col4 {
#   background-color: #ef5b8d;
#   color: #f1f1f1;
# }
# #T_3303c_row16_col5, #T_3303c_row21_col3, #T_3303c_row22_col3 {
#   background-color: #fbdfe8;
#   color: #000000;
# }
# #T_3303c_row17_col4 {
#   background-color: #f9c9d9;
#   color: #000000;
# }
# #T_3303c_row17_col5 {
#   background-color: #f9c8d9;
#   color: #000000;
# }
# #T_3303c_row18_col3, #T_3303c_row20_col3 {
#   background-color: #fbd6e2;
#   color: #000000;
# }
# #T_3303c_row18_col5 {
#   background-color: #f282a8;
#   color: #f1f1f1;
# }
# #T_3303c_row19_col3 {
#   background-color: #facddc;
#   color: #000000;
# }
# #T_3303c_row20_col5 {
#   background-color: #f384aa;
#   color: #f1f1f1;
# }
# #T_3303c_row21_col5 {
#   background-color: #f8bdd1;
#   color: #000000;
# }
# </style>
# <table id="T_3303c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3303c_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_3303c_level0_col1" class="col_heading level0 col1" >Scheme</th>
#       <th id="T_3303c_level0_col2" class="col_heading level0 col2" >Fold</th>
#       <th id="T_3303c_level0_col3" class="col_heading level0 col3" >Training Time (Minutes)</th>
#       <th id="T_3303c_level0_col4" class="col_heading level0 col4" >Final Epoch</th>
#       <th id="T_3303c_level0_col5" class="col_heading level0 col5" >Best F1-Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3303c_level0_row0" class="row_heading level0 row0" >23</th>
#       <td id="T_3303c_row0_col0" class="data row0 col0" >holdout</td>
#       <td id="T_3303c_row0_col1" class="data row0 col1" >HO_70_15_15</td>
#       <td id="T_3303c_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_3303c_row0_col3" class="data row0 col3" >2.89</td>
#       <td id="T_3303c_row0_col4" class="data row0 col4" >6.000000</td>
#       <td id="T_3303c_row0_col5" class="data row0 col5" >0.7772</td>
#     </tr>
#     <tr>
#       <th id="T_3303c_level0_row1" class="row_heading level0 row1" >24</th>
#       <td id="T_3303c_row1_col0" class="data row1 col0" >holdout</td>
#       <td id="T_3303c_row1_col1" class="data row1 col1" >HO_80_10_10</td>
#       <td id="T_3303c_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_3303c_row1_col3" class="data row1 col3" >3.66</td>
#       <td id="T_3303c_row1_col4" class="data row1 col4" >7.000000</td>
#       <td id="T_3303c_row1_col5" class="data row1 col5" >0.7823</td>
#     </tr>
#     <tr>
#       <th id="T_3303c_level0_row2" class="row_heading level0 row2" >25</th>
#       <td id="T_3303c_row2_col0" class="data row2 col0" >holdout</td>
#       <td id="T_3303c_row2_col1" class="data row2 col1" >HO_90_05_05</td>
#       <td id="T_3303c_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_3303c_row2_col3" class="data row2 col3" >2.88</td>
#       <td id="T_3303c_row2_col4" class="data row2 col4" >6.000000</td>
#       <td id="T_3303c_row2_col5" class="data row2 col5" >0.7772</td>
#     </tr>
#     <tr>
#       <th id="T_3303c_level0_row3" class="row_heading level0 row3" >26</th>
#       <td id="T_3303c_row3_col0" class="data row3 col0" >kfold</td>
#       <td id="T_3303c_row3_col1" class="data row3 col1" >k2</td>
#       <td id="T_3303c_row3_col2" class="data row3 col2" >fold1</td>
#       <td id="T_3303c_row3_col3" class="data row3 col3" >2.55</td>
#       <td id="T_3303c_row3_col4" class="data row3 col4" >6.000000</td>
#       <td id="T_3303c_row3_col5" class="data row3 col5" >0.7675</td>
#     </tr>
#     <tr>
#       <th id="T_3303c_level0_row4" class="row_heading level0 row4" >27</th>
#       <td id="T_3303c_row4_col0" class="data row4 col0" >kfold</td>
#       <td id="T_3303c_row4_col1" class="data row4 col1" >k2</td>
#       <td id="T_3303c_row4_col2" class="data row4 col2" >fold2</td>
#       <td id="T_3303c_row4_col3" class="data row4 col3" >2.54</td>
#       <td id="T_3303c_row4_col4" class="data row4 col4" >6.000000</td>
#       <td id="T_3303c_row4_col5" class="data row4 col5" >0.7616</td>
#     </tr>
#     <tr>
#       <th id="T_3303c_level0_row5" class="row_heading level0 row5" >28</th>
#       <td id="T_3303c_row5_col0" class="data row5 col0" >kfold</td>
#       <td id="T_3303c_row5_col1" class="data row5 col1" >k3</td>
#       <td id="T_3303c_row5_col2" class="data row5 col2" >fold1</td>
#       <td id="T_3303c_row5_col3" class="data row5 col3" >3.37</td>
#       <td id="T_3303c_row5_col4" class="data row5 col4" >7.000000</td>
#       <td id="T_3303c_row5_col5" class="data row5 col5" >0.7866</td>
#     </tr>
#     <tr>
#       <th id="T_3303c_level0_row6" class="row_heading level0 row6" >29</th>
#       <td id="T_3303c_row6_col0" class="data row6 col0" >kfold</td>
#       <td id="T_3303c_row6_col1" class="data row6 col1" >k3</td>
#       <td id="T_3303c_row6_col2" class="data row6 col2" >fold2</td>
#       <td id="T_3303c_row6_col3" class="data row6 col3" >2.41</td>
#       <td id="T_3303c_row6_col4" class="data row6 col4" >5.000000</td>
#       <td id="T_3303c_row6_col5" class="data row6 col5" >0.7692</td>
#     </tr>
#     <tr>
#       <th id="T_3303c_level0_row7" class="row_heading level0 row7" >30</th>
#       <td id="T_3303c_row7_col0" class="data row7 col0" >kfold</td>
#       <td id="T_3303c_row7_col1" class="data row7 col1" >k3</td>
#       <td id="T_3303c_row7_col2" class="data row7 col2" >fold3</td>
#       <td id="T_3303c_row7_col3" class="data row7 col3" >2.91</td>
#       <td id="T_3303c_row7_col4" class="data row7 col4"
# ===== TRAINING TIME TABLE | IndoRoBERTa =====
# <style type="text/css">
# #T_4bf72_row0_col3 {
#   background-color: #f8c0d3;
#   color: #000000;
# }
# #T_4bf72_row0_col4, #T_4bf72_row2_col4, #T_4bf72_row6_col4, #T_4bf72_row9_col4, #T_4bf72_row19_col4, #T_4bf72_row21_col4, #T_4bf72_row22_col4 {
#   background-color: #f8bbd0;
#   color: #000000;
# }
# #T_4bf72_row0_col5, #T_4bf72_row2_col5 {
#   background-color: #f7aec7;
#   color: #000000;
# }
# #T_4bf72_row1_col3, #T_4bf72_row1_col4, #T_4bf72_row10_col3, #T_4bf72_row10_col4, #T_4bf72_row14_col5, #T_4bf72_row19_col5 {
#   background-color: #fce4ec;
#   color: #000000;
# }
# #T_4bf72_row1_col5 {
#   background-color: #ef6292;
#   color: #f1f1f1;
# }
# #T_4bf72_row2_col3, #T_4bf72_row5_col5 {
#   background-color: #f9c0d4;
#   color: #000000;
# }
# #T_4bf72_row3_col3 {
#   background-color: #f27ea5;
#   color: #f1f1f1;
# }
# #T_4bf72_row3_col4, #T_4bf72_row5_col3, #T_4bf72_row5_col4, #T_4bf72_row20_col5 {
#   background-color: #ec407a;
#   color: #f1f1f1;
# }
# #T_4bf72_row3_col5 {
#   background-color: #fad4e1;
#   color: #000000;
# }
# #T_4bf72_row4_col3 {
#   background-color: #f8bcd1;
#   color: #000000;
# }
# #T_4bf72_row4_col4, #T_4bf72_row11_col4, #T_4bf72_row15_col4 {
#   background-color: #f27da4;
#   color: #f1f1f1;
# }
# #T_4bf72_row4_col5 {
#   background-color: #fbdde7;
#   color: #000000;
# }
# #T_4bf72_row6_col3 {
#   background-color: #f8bed2;
#   color: #000000;
# }
# #T_4bf72_row6_col5 {
#   background-color: #f8bfd3;
#   color: #000000;
# }
# #T_4bf72_row7_col3 {
#   background-color: #fad3e0;
#   color: #000000;
# }
# #T_4bf72_row7_col4, #T_4bf72_row7_col5, #T_4bf72_row8_col4, #T_4bf72_row12_col4, #T_4bf72_row12_col5, #T_4bf72_row13_col4, #T_4bf72_row14_col4, #T_4bf72_row16_col4, #T_4bf72_row17_col4, #T_4bf72_row18_col4, #T_4bf72_row20_col4 {
#   background-color: #facfde;
#   color: #000000;
# }
# #T_4bf72_row8_col3 {
#   background-color: #facddc;
#   color: #000000;
# }
# #T_4bf72_row8_col5 {
#   background-color: #facbdb;
#   color: #000000;
# }
# #T_4bf72_row9_col3 {
#   background-color: #f6a8c3;
#   color: #000000;
# }
# #T_4bf72_row9_col5, #T_4bf72_row18_col3, #T_4bf72_row20_col3 {
#   background-color: #f9c5d7;
#   color: #000000;
# }
# #T_4bf72_row10_col5 {
#   background-color: #f59fbc;
#   color: #000000;
# }
# #T_4bf72_row11_col3 {
#   background-color: #ef6392;
#   color: #f1f1f1;
# }
# #T_4bf72_row11_col5 {
#   background-color: #fad5e1;
#   color: #000000;
# }
# #T_4bf72_row12_col3 {
#   background-color: #f9c7d8;
#   color: #000000;
# }
# #T_4bf72_row13_col3 {
#   background-color: #f9c9da;
#   color: #000000;
# }
# #T_4bf72_row13_col5 {
#   background-color: #f16f9b;
#   color: #f1f1f1;
# }
# #T_4bf72_row14_col3 {
#   background-color: #f9c9d9;
#   color: #000000;
# }
# #T_4bf72_row15_col3 {
#   background-color: #ed4e84;
#   color: #f1f1f1;
# }
# #T_4bf72_row15_col5 {
#   background-color: #f06997;
#   color: #f1f1f1;
# }
# #T_4bf72_row16_col3, #T_4bf72_row17_col5, #T_4bf72_row22_col5 {
#   background-color: #f9c8d9;
#   color: #000000;
# }
# #T_4bf72_row16_col5 {
#   background-color: #fbdfe8;
#   color: #000000;
# }
# #T_4bf72_row17_col3 {
#   background-color: #f9c6d7;
#   color: #000000;
# }
# #T_4bf72_row18_col5 {
#   background-color: #ef5d8e;
#   color: #f1f1f1;
# }
# #T_4bf72_row19_col3, #T_4bf72_row22_col3 {
#   background-color: #f48fb1;
#   color: #000000;
# }
# #T_4bf72_row21_col3 {
#   background-color: #f38baf;
#   color: #f1f1f1;
# }
# #T_4bf72_row21_col5 {
#   background-color: #f496b6;
#   color: #000000;
# }
# </style>
# <table id="T_4bf72" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4bf72_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_4bf72_level0_col1" class="col_heading level0 col1" >Scheme</th>
#       <th id="T_4bf72_level0_col2" class="col_heading level0 col2" >Fold</th>
#       <th id="T_4bf72_level0_col3" class="col_heading level0 col3" >Training Time (Minutes)</th>
#       <th id="T_4bf72_level0_col4" class="col_heading level0 col4" >Final Epoch</th>
#       <th id="T_4bf72_level0_col5" class="col_heading level0 col5" >Best F1-Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bf72_level0_row0" class="row_heading level0 row0" >46</th>
#       <td id="T_4bf72_row0_col0" class="data row0 col0" >holdout</td>
#       <td id="T_4bf72_row0_col1" class="data row0 col1" >HO_70_15_15</td>
#       <td id="T_4bf72_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_4bf72_row0_col3" class="data row0 col3" >3.06</td>
#       <td id="T_4bf72_row0_col4" class="data row0 col4" >6.000000</td>
#       <td id="T_4bf72_row0_col5" class="data row0 col5" >0.7290</td>
#     </tr>
#     <tr>
#       <th id="T_4bf72_level0_row1" class="row_heading level0 row1" >47</th>
#       <td id="T_4bf72_row1_col0" class="data row1 col0" >holdout</td>
#       <td id="T_4bf72_row1_col1" class="data row1 col1" >HO_80_10_10</td>
#       <td id="T_4bf72_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_4bf72_row1_col3" class="data row1 col3" >2.22</td>
#       <td id="T_4bf72_row1_col4" class="data row1 col4" >4.000000</td>
#       <td id="T_4bf72_row1_col5" class="data row1 col5" >0.7432</td>
#     </tr>
#     <tr>
#       <th id="T_4bf72_level0_row2" class="row_heading level0 row2" >48</th>
#       <td id="T_4bf72_row2_col0" class="data row2 col0" >holdout</td>
#       <td id="T_4bf72_row2_col1" class="data row2 col1" >HO_90_05_05</td>
#       <td id="T_4bf72_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_4bf72_row2_col3" class="data row2 col3" >3.05</td>
#       <td id="T_4bf72_row2_col4" class="data row2 col4" >6.000000</td>
#       <td id="T_4bf72_row2_col5" class="data row2 col5" >0.7290</td>
#     </tr>
#     <tr>
#       <th id="T_4bf72_level0_row3" class="row_heading level0 row3" >49</th>
#       <td id="T_4bf72_row3_col0" class="data row3 col0" >kfold</td>
#       <td id="T_4bf72_row3_col1" class="data row3 col1" >k2</td>
#       <td id="T_4bf72_row3_col2" class="data row3 col2" >fold1</td>
#       <td id="T_4bf72_row3_col3" class="data row3 col3" >3.64</td>
#       <td id="T_4bf72_row3_col4" class="data row3 col4" >8.000000</td>
#       <td id="T_4bf72_row3_col5" class="data row3 col5" >0.7126</td>
#     </tr>
#     <tr>
#       <th id="T_4bf72_level0_row4" class="row_heading level0 row4" >50</th>
#       <td id="T_4bf72_row4_col0" class="data row4 col0" >kfold</td>
#       <td id="T_4bf72_row4_col1" class="data row4 col1" >k2</td>
#       <td id="T_4bf72_row4_col2" class="data row4 col2" >fold2</td>
#       <td id="T_4bf72_row4_col3" class="data row4 col3" >3.15</td>
#       <td id="T_4bf72_row4_col4" class="data row4 col4" >7.000000</td>
#       <td id="T_4bf72_row4_col5" class="data row4 col5" >0.7075</td>
#     </tr>
#     <tr>
#       <th id="T_4bf72_level0_row5" class="row_heading level0 row5" >51</th>
#       <td id="T_4bf72_row5_col0" class="data row5 col0" >kfold</td>
#       <td id="T_4bf72_row5_col1" class="data row5 col1" >k3</td>
#       <td id="T_4bf72_row5_col2" class="data row5 col2" >fold1</td>
#       <td id="T_4bf72_row5_col3" class="data row5 col3" >4.13</td>
#       <td id="T_4bf72_row5_col4" class="data row5 col4" >8.000000</td>
#       <td id="T_4bf72_row5_col5" class="data row5 col5" >0.7236</td>
#     </tr>
#     <tr>
#       <th id="T_4bf72_level0_row6" class="row_heading level0 row6" >52</th>
#       <td id="T_4bf72_row6_col0" class="data row6 col0" >kfold</td>
#       <td id="T_4bf72_row6_col1" class="data row6 col1" >k3</td>
#       <td id="T_4bf72_row6_col2" class="data row6 col2" >fold2</td>
#       <td id="T_4bf72_row6_col3" class="data row6 col3" >3.09</td>
#       <td id="T_4bf72_row6_col4" class="data row6 col4" >6.000000</td>
#       <td id="T_4bf72_row6_col5" class="data row6 col5" >0.7244</td>
#     </tr>
#     <tr>
#       <th id="T_4bf72_level0_row7" class="row_heading level0 row7" >53</th>
#       <td id="T_4bf72_row7_col0" class="data row7 col0" >kfold</td>
#       <td id="T_4bf72_row7_col1" class="data row7 col1" >k3</td>
#       <td id="T_4bf72_row7_col2" class="data row7 col2" >fold3</td>
#       <td id="T_4bf72_row7_col3" class="data row7 col3" >2.61</td>
#       <td id="T_4bf72_row7_col4" class="data row7 col4" >5.000000</td>
#       <td id="T_4bf72_row7_col5" class="data row7 col5" >0.7152</td>
#     </tr>
#     <tr>
#       <th id="T_4bf72_level0_row8" class="row_
# Saved: /content/drive/MyDrive/SKRIPSI/models/summary_training_time_per_model.csv

# %%
cols_show = [
    "Model", "Split", "Scheme", "Fold",
    "Training Time (Minutes)", "Final Epoch", "Best F1-Macro"
]

styled = (
    df_13[cols_show].style
    # HEADER STYLE
    .set_table_styles([
        {"selector": "th",
         "props": [
             ("background-color", "#EC407A"),
             ("color", "white"),
             ("text-align", "center"),
             ("border", "1px solid #AD1457")
         ]},
        {"selector": "td",
         "props": [
             ("border", "1px solid #F06292")
         ]}
    ])
    # Semua kolom pink muda
    .set_properties(subset=[
        "Model", "Split", "Scheme", "Fold",
        "Training Time (Minutes)", "Final Epoch"
    ], **{
        "background-color": "#FCE4EC",
        "color": "black",
        "text-align": "center"
    })
    # F1 tetap gradasi
    .background_gradient(
        subset=["Best F1-Macro"],
        cmap=LinearSegmentedColormap.from_list(
            "pink_grad",
            ["#FCE4EC", "#F48FB1", "#C2185B"]
        )
    )
    .format({
        "Training Time (Minutes)": lambda x: "-" if pd.isna(x) else f"{x:.2f}",
        "Best F1-Macro": lambda x: "-" if pd.isna(x) else f"{x:.4f}",
    })
)

display(styled)
# Out:
# <style type="text/css">
# #T_20797 th {
#   background-color: #EC407A;
#   color: white;
#   text-align: center;
#   border: 1px solid #AD1457;
# }
# #T_20797 td {
#   border: 1px solid #F06292;
# }
# #T_20797_row0_col0, #T_20797_row0_col1, #T_20797_row0_col2, #T_20797_row0_col3, #T_20797_row0_col4, #T_20797_row0_col5, #T_20797_row1_col0, #T_20797_row1_col1, #T_20797_row1_col2, #T_20797_row1_col3, #T_20797_row1_col4, #T_20797_row1_col5, #T_20797_row2_col0, #T_20797_row2_col1, #T_20797_row2_col2, #T_20797_row2_col3, #T_20797_row2_col4, #T_20797_row2_col5, #T_20797_row3_col0, #T_20797_row3_col1, #T_20797_row3_col2, #T_20797_row3_col3, #T_20797_row3_col4, #T_20797_row3_col5, #T_20797_row4_col0, #T_20797_row4_col1, #T_20797_row4_col2, #T_20797_row4_col3, #T_20797_row4_col4, #T_20797_row4_col5, #T_20797_row5_col0, #T_20797_row5_col1, #T_20797_row5_col2, #T_20797_row5_col3, #T_20797_row5_col4, #T_20797_row5_col5, #T_20797_row6_col0, #T_20797_row6_col1, #T_20797_row6_col2, #T_20797_row6_col3, #T_20797_row6_col4, #T_20797_row6_col5, #T_20797_row7_col0, #T_20797_row7_col1, #T_20797_row7_col2, #T_20797_row7_col3, #T_20797_row7_col4, #T_20797_row7_col5, #T_20797_row8_col0, #T_20797_row8_col1, #T_20797_row8_col2, #T_20797_row8_col3, #T_20797_row8_col4, #T_20797_row8_col5, #T_20797_row9_col0, #T_20797_row9_col1, #T_20797_row9_col2, #T_20797_row9_col3, #T_20797_row9_col4, #T_20797_row9_col5, #T_20797_row10_col0, #T_20797_row10_col1, #T_20797_row10_col2, #T_20797_row10_col3, #T_20797_row10_col4, #T_20797_row10_col5, #T_20797_row11_col0, #T_20797_row11_col1, #T_20797_row11_col2, #T_20797_row11_col3, #T_20797_row11_col4, #T_20797_row11_col5, #T_20797_row12_col0, #T_20797_row12_col1, #T_20797_row12_col2, #T_20797_row12_col3, #T_20797_row12_col4, #T_20797_row12_col5 {
#   background-color: #FCE4EC;
#   color: black;
#   text-align: center;
# }
# #T_20797_row0_col6 {
#   background-color: #d7497f;
#   color: #f1f1f1;
# }
# #T_20797_row1_col6 {
#   background-color: #e56b97;
#   color: #f1f1f1;
# }
# #T_20797_row2_col6 {
#   background-color: #d6487d;
#   color: #f1f1f1;
# }
# #T_20797_row3_col6, #T_20797_row5_col6 {
#   background-color: #ea78a0;
#   color: #f1f1f1;
# }
# #T_20797_row4_col6 {
#   background-color: #e46996;
#   color: #f1f1f1;
# }
# #T_20797_row6_col6, #T_20797_row8_col6 {
#   background-color: #fce4ec;
#   color: #000000;
# }
# #T_20797_row7_col6 {
#   background-color: #f9c7d8;
#   color: #000000;
# }
# #T_20797_row9_col6 {
#   background-color: #c2185b;
#   color: #f1f1f1;
# }
# #T_20797_row10_col6 {
#   background-color: #d5457b;
#   color: #f1f1f1;
# }
# #T_20797_row11_col6 {
#   background-color: #f9c5d6;
#   color: #000000;
# }
# #T_20797_row12_col6 {
#   background-color: #f8b9ce;
#   color: #000000;
# }
# </style>
# <table id="T_20797" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20797_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_20797_level0_col1" class="col_heading level0 col1" >Split</th>
#       <th id="T_20797_level0_col2" class="col_heading level0 col2" >Scheme</th>
#       <th id="T_20797_level0_col3" class="col_heading level0 col3" >Fold</th>
#       <th id="T_20797_level0_col4" class="col_heading level0 col4" >Training Time (Minutes)</th>
#       <th id="T_20797_level0_col5" class="col_heading level0 col5" >Final Epoch</th>
#       <th id="T_20797_level0_col6" class="col_heading level0 col6" >Best F1-Macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20797_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_20797_row0_col0" class="data row0 col0" >IndoBERT</td>
#       <td id="T_20797_row0_col1" class="data row0 col1" >holdout</td>
#       <td id="T_20797_row0_col2" class="data row0 col2" >HO_70_15_15</td>
#       <td id="T_20797_row0_col3" class="data row0 col3" >None</td>
#       <td id="T_20797_row0_col4" class="data row0 col4" >4.06</td>
#       <td id="T_20797_row0_col5" class="data row0 col5" >8.000000</td>
#       <td id="T_20797_row0_col6" class="data row0 col6" >0.7929</td>
#     </tr>
#     <tr>
#       <th id="T_20797_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_20797_row1_col0" class="data row1 col0" >IndoBERT</td>
#       <td id="T_20797_row1_col1" class="data row1 col1" >holdout</td>
#       <td id="T_20797_row1_col2" class="data row1 col2" >HO_80_10_10</td>
#       <td id="T_20797_row1_col3" class="data row1 col3" >None</td>
#       <td id="T_20797_row1_col4" class="data row1 col4" >3.29</td>
#       <td id="T_20797_row1_col5" class="data row1 col5" >6.000000</td>
#       <td id="T_20797_row1_col6" class="data row1 col6" >0.7815</td>
#     </tr>
#     <tr>
#       <th id="T_20797_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_20797_row2_col0" class="data row2 col0" >IndoBERT</td>
#       <td id="T_20797_row2_col1" class="data row2 col1" >holdout</td>
#       <td id="T_20797_row2_col2" class="data row2 col2" >HO_90_05_05</td>
#       <td id="T_20797_row2_col3" class="data row2 col3" >None</td>
#       <td id="T_20797_row2_col4" class="data row2 col4" >4.07</td>
#       <td id="T_20797_row2_col5" class="data row2 col5" >8.000000</td>
#       <td id="T_20797_row2_col6" class="data row2 col6" >0.7937</td>
#     </tr>
#     <tr>
#       <th id="T_20797_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_20797_row3_col0" class="data row3 col0" >IndoBERTweet</td>
#       <td id="T_20797_row3_col1" class="data row3 col1" >holdout</td>
#       <td id="T_20797_row3_col2" class="data row3 col2" >HO_70_15_15</td>
#       <td id="T_20797_row3_col3" class="data row3 col3" >None</td>
#       <td id="T_20797_row3_col4" class="data row3 col4" >2.89</td>
#       <td id="T_20797_row3_col5" class="data row3 col5" >6.000000</td>
#       <td id="T_20797_row3_col6" class="data row3 col6" >0.7772</td>
#     </tr>
#     <tr>
#       <th id="T_20797_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_20797_row4_col0" class="data row4 col0" >IndoBERTweet</td>
#       <td id="T_20797_row4_col1" class="data row4 col1" >holdout</td>
#       <td id="T_20797_row4_col2" class="data row4 col2" >HO_80_10_10</td>
#       <td id="T_20797_row4_col3" class="data row4 col3" >None</td>
#       <td id="T_20797_row4_col4" class="data row4 col4" >3.66</td>
#       <td id="T_20797_row4_col5" class="data row4 col5" >7.000000</td>
#       <td id="T_20797_row4_col6" class="data row4 col6" >0.7823</td>
#     </tr>
#     <tr>
#       <th id="T_20797_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_20797_row5_col0" class="data row5 col0" >IndoBERTweet</td>
#       <td id="T_20797_row5_col1" class="data row5 col1" >holdout</td>
#       <td id="T_20797_row5_col2" class="data row5 col2" >HO_90_05_05</td>
#       <td id="T_20797_row5_col3" class="data row5 col3" >None</td>
#       <td id="T_20797_row5_col4" class="data row5 col4" >2.88</td>
#       <td id="T_20797_row5_col5" class="data row5 col5" >6.000000</td>
#       <td id="T_20797_row5_col6" class="data row5 col6" >0.7772</td>
#     </tr>
#     <tr>
#       <th id="T_20797_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_20797_row6_col0" class="data row6 col0" >IndoRoBERTa</td>
#       <td id="T_20797_row6_col1" class="data row6 col1" >holdout</td>
#       <td id="T_20797_row6_col2" class="data row6 col2" >HO_70_15_15</td>
#       <td id="T_20797_row6_col3" class="data row6 col3" >None</td>
#       <td id="T_20797_row6_col4" class="data row6 col4" >3.06</td>
#       <td id="T_20797_row6_col5" class="data row6 col5" >6.000000</td>
#       <td id="T_20797_row6_col6" class="data row6 col6" >0.7290</td>
#     </tr>
#     <tr>
#       <th id="T_20797_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_20797_row7_col0" class="data row7 col0" >IndoRoBERTa</td>
#       <td id="T_20797_row7_col1" class="data row7 col1" >holdout</td>
#       <td id="T_20797_row7_col2" class="data row7 col2" >HO_80_10_10</td>
#       <td id="T_20797_row7_col3" class="data row7 col3" >None</td>
#       <td id="T_20797_row7_col4" class="data row7 col4" >2.22</td>
#       <td id="T_20797_row7_col5" class="data row7 col5" >4.000000</td>
#       <td id="T_20797_row7_c

# %%
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap

HOLDOUT_CSV = "/content/drive/MyDrive/SKRIPSI/results/results_holdout_final.csv"
KFOLD_CSV   = "/content/drive/MyDrive/SKRIPSI/results/results_kfold_progress.csv"

df_ho = pd.read_csv(HOLDOUT_CSV)
df_kf = pd.read_csv(KFOLD_CSV)

# Bersihkan nama kolom
for df in (df_ho, df_kf):
    df.columns = df.columns.str.strip().str.lower()

# Tambahkan kolom fold kalau tidak ada (untuk holdout)
if "fold" not in df_ho.columns:
    df_ho["fold"] = None

# Gabung
df_all = pd.concat([df_ho, df_kf], ignore_index=True)

# Rapikan string
df_all["split_type"] = df_all["split_type"].astype(str).str.strip().str.lower()
df_all["scheme"] = df_all["scheme"].astype(str).str.strip().str.lower()
df_all["fold"] = df_all["fold"].astype(str).str.strip().str.lower()
df_all["model"] = df_all["model"].astype(str).str.strip()

print("Kolom tersedia:", df_all.columns.tolist())
# Out:
# Kolom tersedia: ['split_type', 'scheme', 'model', 'train_time_sec', 'eval_loss', 'eval_accuracy', 'eval_precision_macro', 'eval_recall_macro', 'eval_f1_macro', 'saved_to', 'fold']

# %%
import re
import pandas as pd
from matplotlib.colors import LinearSegmentedColormap

HOLDOUT_CSV = "/content/drive/MyDrive/SKRIPSI/results/results_holdout_final.csv"
KFOLD_CSV   = "/content/drive/MyDrive/SKRIPSI/results/results_kfold_progress.csv"

df_ho = pd.read_csv(HOLDOUT_CSV)
df_kf = pd.read_csv(KFOLD_CSV)

# lower + strip column names
for df in (df_ho, df_kf):
    df.columns = df.columns.str.strip().str.lower()

# make sure fold exists in holdout
if "fold" not in df_ho.columns:
    df_ho["fold"] = None

df_all = pd.concat([df_ho, df_kf], ignore_index=True)

# basic cleaning
for c in ["split_type", "scheme", "fold", "model"]:
    if c in df_all.columns:
        df_all[c] = df_all[c].astype(str).str.strip()

# ---------- NORMALIZER ----------
def norm_split(x: str) -> str:
    x = (x or "").lower()
    if "hold" in x:
        return "holdout"
    if "k" in x and "fold" in x:
        return "kfold"
    if "cv" in x:
        return "kfold"
    # fallback: if scheme looks like k*
    return "kfold" if re.search(r"\bk\s*=?\s*\d+", x) else x

def norm_k(x: str) -> str:
    x = (x or "").lower().replace(" ", "")
    # examples: "k5", "k=5", "5", "k-fold5"
    m = re.search(r"k=?(\d+)", x)
    if m:
        return f"k{m.group(1)}"
    m = re.fullmatch(r"(\d+)", x)
    if m:
        return f"k{m.group(1)}"
    return x

def norm_fold(x: str) -> str:
    x = (x or "").lower().replace(" ", "")
    # examples: "fold2", "fold_2", "2", "f2"
    m = re.search(r"fold_?(\d+)", x)
    if m:
        return f"fold{m.group(1)}"
    m = re.search(r"\bf(\d+)\b", x)
    if m:
        return f"fold{m.group(1)}"
    m = re.fullmatch(r"(\d+)", x)
    if m:
        return f"fold{m.group(1)}"
    # holdout case like "none"
    return None if x in ["none", "nan", "null", ""] else x

df_all["split_norm"] = df_all["split_type"].apply(norm_split)
df_all["scheme_norm"] = df_all["scheme"].apply(norm_k)
df_all["fold_norm"] = df_all["fold"].apply(norm_fold)
df_all["model_norm"] = df_all["model"].str.lower()

# quick sanity print (biar kamu lihat bentuknya)
print("split_norm unique:", df_all["split_norm"].unique())
print("scheme_norm unique:", sorted([x for x in df_all["scheme_norm"].unique() if isinstance(x,str)]))
print("fold_norm unique:", sorted([x for x in df_all["fold_norm"].unique() if isinstance(x,str)])[:15], "...")

# ---------- FILTER 13 RUNS ----------
keep_holdout = df_all[df_all["split_norm"] == "holdout"].copy()

keep_k5f2_tweet = df_all[
    (df_all["split_norm"] == "kfold") &
    (df_all["scheme_norm"] == "k5") &
    (df_all["fold_norm"] == "fold2") &
    (df_all["model_norm"].str.contains("tweet"))
].copy()

keep_k6f2 = df_all[
    (df_all["split_norm"] == "kfold") &
    (df_all["scheme_norm"] == "k6") &
    (df_all["fold_norm"] == "fold2") &
    (
        df_all["model_norm"].str.contains("tweet") |
        df_all["model_norm"].str.contains("roberta")
    )
].copy()

keep_k6f4_roberta = df_all[
    (df_all["split_norm"] == "kfold") &
    (df_all["scheme_norm"] == "k6") &
    (df_all["fold_norm"] == "fold4") &
    (df_all["model_norm"].str.contains("roberta"))
].copy()

df_13 = pd.concat([keep_holdout, keep_k5f2_tweet, keep_k6f2, keep_k6f4_roberta], ignore_index=True)
df_13 = df_13.drop_duplicates(subset=["split_norm","scheme_norm","fold_norm","model"]).reset_index(drop=True)

print("Total rows (expected 13):", len(df_13))

# ---------- DISPLAY METRICS ONLY ----------
cols_metrics = [
    "split_norm","scheme_norm","fold_norm","model",
    "eval_accuracy","eval_precision_macro","eval_recall_macro","eval_f1_macro"
]

pink_grad = LinearSegmentedColormap.from_list("pink_grad", ["#FCE4EC", "#F48FB1", "#C2185B"])

display(
    df_13[cols_metrics].sort_values(["split_norm","model","scheme_norm","fold_norm"]).style
    .set_table_styles([
        {"selector": "th", "props": [
            ("background-color", "#EC407A"),
            ("color", "white"),
            ("border", "1px solid #AD1457"),
            ("text-align", "center")
        ]},
        {"selector": "td", "props": [
            ("border", "1px solid #F06292"),
            ("text-align", "center")
        ]}
    ])
    .set_properties(subset=[
        "split_norm","scheme_norm","fold_norm","model",
        "eval_accuracy","eval_precision_macro","eval_recall_macro"
    ], **{
        "background-color": "#FCE4EC",
        "color": "black"
    })
    .background_gradient(subset=["eval_f1_macro"], cmap=pink_grad)
    .format({
        "eval_accuracy": "{:.4f}",
        "eval_precision_macro": "{:.4f}",
        "eval_recall_macro": "{:.4f}",
        "eval_f1_macro": "{:.4f}",
    })
)
# Out:
# split_norm unique: ['holdout' 'kfold']
# scheme_norm unique: ['ho_70_15_15', 'ho_80_10_10', 'ho_90_05_05', 'k2', 'k3', 'k4', 'k5', 'k6', 'k7']
# fold_norm unique: ['fold1', 'fold2', 'fold3', 'fold4', 'fold5', 'fold6', 'fold7'] ...
# Total rows (expected 13): 13
# <style type="text/css">
# #T_9db27 th {
#   background-color: #EC407A;
#   color: white;
#   border: 1px solid #AD1457;
#   text-align: center;
# }
# #T_9db27 td {
#   border: 1px solid #F06292;
#   text-align: center;
# }
# #T_9db27_row0_col0, #T_9db27_row0_col1, #T_9db27_row0_col2, #T_9db27_row0_col3, #T_9db27_row0_col4, #T_9db27_row0_col5, #T_9db27_row0_col6, #T_9db27_row1_col0, #T_9db27_row1_col1, #T_9db27_row1_col2, #T_9db27_row1_col3, #T_9db27_row1_col4, #T_9db27_row1_col5, #T_9db27_row1_col6, #T_9db27_row2_col0, #T_9db27_row2_col1, #T_9db27_row2_col2, #T_9db27_row2_col3, #T_9db27_row2_col4, #T_9db27_row2_col5, #T_9db27_row2_col6, #T_9db27_row3_col0, #T_9db27_row3_col1, #T_9db27_row3_col2, #T_9db27_row3_col3, #T_9db27_row3_col4, #T_9db27_row3_col5, #T_9db27_row3_col6, #T_9db27_row4_col0, #T_9db27_row4_col1, #T_9db27_row4_col2, #T_9db27_row4_col3, #T_9db27_row4_col4, #T_9db27_row4_col5, #T_9db27_row4_col6, #T_9db27_row5_col0, #T_9db27_row5_col1, #T_9db27_row5_col2, #T_9db27_row5_col3, #T_9db27_row5_col4, #T_9db27_row5_col5, #T_9db27_row5_col6, #T_9db27_row6_col0, #T_9db27_row6_col1, #T_9db27_row6_col2, #T_9db27_row6_col3, #T_9db27_row6_col4, #T_9db27_row6_col5, #T_9db27_row6_col6, #T_9db27_row7_col0, #T_9db27_row7_col1, #T_9db27_row7_col2, #T_9db27_row7_col3, #T_9db27_row7_col4, #T_9db27_row7_col5, #T_9db27_row7_col6, #T_9db27_row8_col0, #T_9db27_row8_col1, #T_9db27_row8_col2, #T_9db27_row8_col3, #T_9db27_row8_col4, #T_9db27_row8_col5, #T_9db27_row8_col6, #T_9db27_row9_col0, #T_9db27_row9_col1, #T_9db27_row9_col2, #T_9db27_row9_col3, #T_9db27_row9_col4, #T_9db27_row9_col5, #T_9db27_row9_col6, #T_9db27_row10_col0, #T_9db27_row10_col1, #T_9db27_row10_col2, #T_9db27_row10_col3, #T_9db27_row10_col4, #T_9db27_row10_col5, #T_9db27_row10_col6, #T_9db27_row11_col0, #T_9db27_row11_col1, #T_9db27_row11_col2, #T_9db27_row11_col3, #T_9db27_row11_col4, #T_9db27_row11_col5, #T_9db27_row11_col6, #T_9db27_row12_col0, #T_9db27_row12_col1, #T_9db27_row12_col2, #T_9db27_row12_col3, #T_9db27_row12_col4, #T_9db27_row12_col5, #T_9db27_row12_col6 {
#   background-color: #FCE4EC;
#   color: black;
# }
# #T_9db27_row0_col7 {
#   background-color: #d7497f;
#   color: #f1f1f1;
# }
# #T_9db27_row1_col7 {
#   background-color: #e56b97;
#   color: #f1f1f1;
# }
# #T_9db27_row2_col7 {
#   background-color: #d6487d;
#   color: #f1f1f1;
# }
# #T_9db27_row3_col7, #T_9db27_row5_col7 {
#   background-color: #ea78a0;
#   color: #f1f1f1;
# }
# #T_9db27_row4_col7 {
#   background-color: #e46996;
#   color: #f1f1f1;
# }
# #T_9db27_row6_col7, #T_9db27_row8_col7 {
#   background-color: #fce4ec;
#   color: #000000;
# }
# #T_9db27_row7_col7 {
#   background-color: #f9c7d8;
#   color: #000000;
# }
# #T_9db27_row9_col7 {
#   background-color: #c2185b;
#   color: #f1f1f1;
# }
# #T_9db27_row10_col7 {
#   background-color: #d5457b;
#   color: #f1f1f1;
# }
# #T_9db27_row11_col7 {
#   background-color: #f9c5d6;
#   color: #000000;
# }
# #T_9db27_row12_col7 {
#   background-color: #f8b9ce;
#   color: #000000;
# }
# </style>
# <table id="T_9db27" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9db27_level0_col0" class="col_heading level0 col0" >split_norm</th>
#       <th id="T_9db27_level0_col1" class="col_heading level0 col1" >scheme_norm</th>
#       <th id="T_9db27_level0_col2" class="col_heading level0 col2" >fold_norm</th>
#       <th id="T_9db27_level0_col3" class="col_heading level0 col3" >model</th>
#       <th id="T_9db27_level0_col4" class="col_heading level0 col4" >eval_accuracy</th>
#       <th id="T_9db27_level0_col5" class="col_heading level0 col5" >eval_precision_macro</th>
#       <th id="T_9db27_level0_col6" class="col_heading level0 col6" >eval_recall_macro</th>
#       <th id="T_9db27_level0_col7" class="col_heading level0 col7" >eval_f1_macro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9db27_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_9db27_row0_col0" class="data row0 col0" >holdout</td>
#       <td id="T_9db27_row0_col1" class="data row0 col1" >ho_70_15_15</td>
#       <td id="T_9db27_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_9db27_row0_col3" class="data row0 col3" >IndoBERT</td>
#       <td id="T_9db27_row0_col4" class="data row0 col4" >0.7837</td>
#       <td id="T_9db27_row0_col5" class="data row0 col5" >0.7952</td>
#       <td id="T_9db27_row0_col6" class="data row0 col6" >0.7953</td>
#       <td id="T_9db27_row0_col7" class="data row0 col7" >0.7929</td>
#     </tr>
#     <tr>
#       <th id="T_9db27_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_9db27_row1_col0" class="data row1 col0" >holdout</td>
#       <td id="T_9db27_row1_col1" class="data row1 col1" >ho_80_10_10</td>
#       <td id="T_9db27_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_9db27_row1_col3" class="data row1 col3" >IndoBERT</td>
#       <td id="T_9db27_row1_col4" class="data row1 col4" >0.7738</td>
#       <td id="T_9db27_row1_col5" class="data row1 col5" >0.7764</td>
#       <td id="T_9db27_row1_col6" class="data row1 col6" >0.7960</td>
#       <td id="T_9db27_row1_col7" class="data row1 col7" >0.7815</td>
#     </tr>
#     <tr>
#       <th id="T_9db27_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_9db27_row2_col0" class="data row2 col0" >holdout</td>
#       <td id="T_9db27_row2_col1" class="data row2 col1" >ho_90_05_05</td>
#       <td id="T_9db27_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_9db27_row2_col3" class="data row2 col3" >IndoBERT</td>
#       <td id="T_9db27_row2_col4" class="data row2 col4" >0.7865</td>
#       <td id="T_9db27_row2_col5" class="data row2 col5" >0.7939</td>
#       <td id="T_9db27_row2_col6" class="data row2 col6" >0.7985</td>
#       <td id="T_9db27_row2_col7" class="data row2 col7" >0.7937</td>
#     </tr>
#     <tr>
#       <th id="T_9db27_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_9db27_row3_col0" class="data row3 col0" >holdout</td>
#       <td id="T_9db27_row3_col1" class="data row3 col1" >ho_70_15_15</td>
#       <td id="T_9db27_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_9db27_row3_col3" class="data row3 col3" >IndoBERTweet</td>
#       <td id="T_9db27_row3_col4" class="data row3 col4" >0.7685</td>
#       <td id="T_9db27_row3_col5" class="data row3 col5" >0.7686</td>
#       <td id="T_9db27_row3_col6" class="data row3 col6" >0.7928</td>
#       <td id="T_9db27_row3_col7" class="data row3 col7" >0.7772</td>
#     </tr>
#     <tr>
#       <th id="T_9db27_level0_row4" class="row_heading level0 row4" >1</th>
#       <td id="T_9db27_row4_col0" class="data row4 col0" >holdout</td>
#       <td id="T_9db27_row4_col1" class="data row4 col1" >ho_80_10_10</td>
#       <td id="T_9db27_row4_col2" class="data row4 col2" >None</td>
#       <td id="T_9db27_row4_col3" class="data row4 col3" >IndoBERTweet</td>
#       <td id="T_9db27_row4_col4" class="data row4 col4" >0.7724</td>
#       <td id="T_9db27_row4_col5" class="data row4 col5" >0.7750</td>
#       <td id="T_9db27_row4_col6" class="data row4 col6" >0.7961</td>
#       <td id="T_9db27_row4_col7" class="data row4 col7" >0.7823</td>
#     </tr>
#     <tr>
#       <th id="T_9db27_level0_row5" class="row_heading level0 row5" >7</th>
#       <td id="T_9db27_row5_col0" class="data row5 col0" >holdout</td>
#       <td id="T_9db27_row5_col1" class="data row5 col1" >ho_90_05_05</td>
#       <td id="T_9db27_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_9db27_row5_col3" class="data row5 col3" >IndoBERTweet</td>
#       <td id="T_9db27_row5_col4" class="data row5 col4" >0.7685</td>
#       <td id="T_9db27_row5_col5" class="data row5 col5" >0.7686</td>
#       <td id="T_9db27_row5_col6" class="data row5 col6" >0.7928</td>
#       <td id="T_9db27_row5_col7" class="data row5 col7" >0.7772</td>
#     </tr>
#     <tr>
#       <th id="T_9db27_level0_row6" class="row_heading level0 row6" >5</th>
#       <td id="T_9db27_row6_col0" class="data row6 col0" >holdout</td>
#       <td id="T_9db27_row6_col1" class="data row6 col1" >ho_70_15_15</td>
#       <td id="T_9db27_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_9db27_row6_col3" class="data

# %%
def plot_train_vs_val_loss(log_df, title, out_path=None):

    if log_df is None or "epoch" not in log_df.columns:
        return

    train_df = log_df[log_df.get("loss").notna()][["epoch", "loss"]].copy() if "loss" in log_df.columns else pd.DataFrame()
    val_df   = log_df[log_df.get("eval_loss").notna()][["epoch", "eval_loss"]].copy() if "eval_loss" in log_df.columns else pd.DataFrame()

    if train_df.empty and val_df.empty:
        return

    plt.figure()

    if not train_df.empty:
        train_df = train_df.groupby("epoch", as_index=False).mean()
        plt.plot(train_df["epoch"], train_df["loss"], color="#F8BBD0")

    if not val_df.empty:
        val_df = val_df.groupby("epoch", as_index=False).mean()
        plt.plot(val_df["epoch"], val_df["eval_loss"], color="#EC407A")

    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(title)
    plt.legend(["Train Loss", "Val Loss"])

    if out_path:
        plt.savefig(out_path, dpi=200, bbox_inches="tight")

    plt.show()
    plt.close()

# %%
def plot_confusion_matrix(true_labels, pred_labels, title, out_path=None):

    cm = confusion_matrix(true_labels, pred_labels)

    plt.figure()
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot(cmap=pink_cmap, values_format="d")

    plt.title(title)

    if out_path:
        plt.savefig(out_path, dpi=200, bbox_inches="tight")

    plt.show()
    plt.close()

# %%
rows = []

for model_name, split_type, scheme_name, fold_name, run_dir in iter_run_dirs(BASE_MODELS_DIR):
    tag = f"{model_name} | {split_type} | {scheme_name}" + (f" | {fold_name}" if fold_name else "")
    print("\n=== ", tag, "===")

    # 1) Loss curve
    log_df = get_log_df(run_dir)
    loss_png = os.path.join(
        PLOT_OUT_DIR,
        f"LOSS__{model_name}__{split_type}__{scheme_name}" + (f"__{fold_name}" if fold_name else "") + ".png"
    )
    plot_train_vs_val_loss(log_df, title=f"Loss Curve - {tag}", out_path=loss_png)

    # 2) Confusion matrix + metrics
    pred_path = get_val_pred_path(run_dir)
    if pred_path:
        pred_df = pd.read_csv(pred_path)
        y_true = pred_df["true_label"].values
        y_pred = pred_df["pred_label"].values

        acc, prec, rec, f1 = compute_metrics_from_preds(y_true, y_pred)

        cm_png = os.path.join(
            PLOT_OUT_DIR,
            f"CM__{model_name}__{split_type}__{scheme_name}" + (f"__{fold_name}" if fold_name else "") + ".png"
        )
        plot_confusion_matrix(y_true, y_pred, title=f"Confusion Matrix - {tag}", out_path=cm_png)

        rows.append({
            "Model": model_name,
            "Split": split_type,
            "Scheme": scheme_name,
            "Fold": fold_name,
            "Accuracy": acc,
            "Precision_Macro": prec,
            "Recall_Macro": rec,
            "F1_Macro": f1,
            "RunDir": run_dir
        })
    else:
        print("  (skip CM) val_predictions.csv tidak ditemukan di:", run_dir)

df_eval = pd.DataFrame(rows)
csv_path = os.path.join(PLOT_OUT_DIR, "eval_from_val_predictions.csv")
df_eval.to_csv(csv_path, index=False)
print("\nSaved:", csv_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# !zip -r /content/evaluation_results.zip /content/drive/MyDrive/SKRIPSI/models/_plots
# Out:
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/ (stored 0%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__holdout__HO_70_15_15.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__holdout__HO_70_15_15.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__holdout__HO_80_10_10.png (deflated 10%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__holdout__HO_80_10_10.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__holdout__HO_90_05_05.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__holdout__HO_90_05_05.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k2__fold1.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k2__fold1.png (deflated 10%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k2__fold2.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k2__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k3__fold1.png (deflated 14%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k3__fold1.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k3__fold2.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k3__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k3__fold3.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k3__fold3.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k4__fold1.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k4__fold1.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k4__fold2.png (deflated 15%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k4__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k4__fold3.png (deflated 14%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k4__fold3.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k4__fold4.png (deflated 14%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k4__fold4.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k5__fold1.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k5__fold1.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k5__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k5__fold2.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k5__fold3.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k5__fold3.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k5__fold4.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k5__fold4.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k5__fold5.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k5__fold5.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k6__fold1.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k6__fold1.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k6__fold2.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k6__fold2.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k6__fold3.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k6__fold3.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k6__fold4.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k6__fold4.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k6__fold5.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k6__fold5.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERT__kfold__k6__fold6.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERT__kfold__k6__fold6.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__holdout__HO_70_15_15.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__holdout__HO_70_15_15.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__holdout__HO_80_10_10.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__holdout__HO_80_10_10.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__holdout__HO_90_05_05.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__holdout__HO_90_05_05.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k2__fold1.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k2__fold1.png (deflated 10%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k2__fold2.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k2__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k3__fold1.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k3__fold1.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k3__fold2.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k3__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k3__fold3.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k3__fold3.png (deflated 10%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k4__fold1.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k4__fold1.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k4__fold2.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k4__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k4__fold3.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k4__fold3.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k4__fold4.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k4__fold4.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k5__fold1.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k5__fold1.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k5__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k5__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k5__fold3.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k5__fold3.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k5__fold4.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k5__fold4.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k5__fold5.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k5__fold5.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k6__fold1.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k6__fold1.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k6__fold2.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k6__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k6__fold3.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k6__fold3.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k6__fold4.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k6__fold4.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k6__fold5.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k6__fold5.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoBERTweet__kfold__k6__fold6.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoBERTweet__kfold__k6__fold6.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__holdout__HO_70_15_15.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__holdout__HO_70_15_15.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__holdout__HO_80_10_10.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__holdout__HO_80_10_10.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__holdout__HO_90_05_05.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__holdout__HO_90_05_05.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k2__fold1.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k2__fold1.png (deflated 10%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k2__fold2.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k2__fold2.png (deflated 10%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k3__fold1.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k3__fold1.png (deflated 10%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k3__fold2.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k3__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k3__fold3.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k3__fold3.png (deflated 10%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k4__fold1.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k4__fold1.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k4__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k4__fold2.png (deflated 10%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k4__fold3.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k4__fold3.png (deflated 10%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k4__fold4.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k4__fold4.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k5__fold1.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k5__fold1.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k5__fold2.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k5__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k5__fold3.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k5__fold3.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k5__fold4.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k5__fold4.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k5__fold5.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k5__fold5.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k6__fold1.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k6__fold1.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k6__fold2.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k6__fold2.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k6__fold3.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k6__fold3.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k6__fold4.png (deflated 13%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k6__fold4.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k6__fold5.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k6__fold5.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/LOSS__IndoRoBERTa__kfold__k6__fold6.png (deflated 11%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/CM__IndoRoBERTa__kfold__k6__fold6.png (deflated 12%)
#   adding: content/drive/MyDrive/SKRIPSI/models/_plots/eval_from_val_predictions.csv (deflated 72%)

# %%
from google.colab import files
files.download("/content/evaluation_results.zip")
